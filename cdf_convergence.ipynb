# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF

# Generate random samples from the uniform distribution
n1 = 10
n2 = 1000
samples1 = np.random.uniform(0, 1, n1)
samples2 = np.random.uniform(0, 1, n2)

# compute the empiricl CDFs 
ecdf1 = ECDF(samples1)
ecdf2 = ECDF(samples2)

# Plot the empirical CDFs and population CDF for n=10
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.step(ecdf1.x, ecdf1.y, label='n=10')
#plt.plot(sorted_samples1, ecdf1, label='n=10')
plt.plot(population_cdf, population_cdf, label='Population CDF')
plt.xlabel('t')
plt.ylabel('CDF value F(t)')
plt.legend()
plt.title('Empirical CDF for Uniform Distribution (n=10)')

# Plot the empirical CDFs and population CDF for n=1000
plt.subplot(1, 2, 2)
plt.step(ecdf2.x, ecdf2.y, label='n=1000')
plt.plot(population_cdf, population_cdf, label='Population CDF')
plt.xlabel('x')
plt.ylabel('CDF value F(t)')
plt.legend()
plt.title('Empirical CDF for Uniform Distribution (n=1000)')

plt.tight_layout()
plt.show()
